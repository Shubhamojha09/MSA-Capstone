# %% [markdown]
# # Fake News Detection

# %% [markdown]
# ## Task 1

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
# Load the datasets
fake_train = pd.read_csv('Fake_train.csv')
fake_dev = pd.read_csv('Fake_dev.csv')

# %%
# Vectorize the text using TF-IDF
vectorizer = TfidfVectorizer()
X_train = vectorizer.fit_transform(fake_train['text'])
y_train = fake_train['label']

# %%
X_dev = vectorizer.transform(fake_dev['text'])
y_dev = fake_dev['label']

# %% [markdown]
# ### Naive Bayes

# %%
# Initialize a Naive Bayes classifier
classifier_nb = MultinomialNB()
classifier_nb.fit(X_train, y_train)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
# Predict on the development set
predictions_nb = classifier_nb.predict(X_dev)

# %%
results_nb = pd.DataFrame({
    'Text': fake_dev['text'],
    'Actual': y_dev,
    'Predicted': predictions_nb
})

# %%
# Calculate the accuracy
accuracy_nb = accuracy_score(y_dev, predictions_nb)
print(f"Accuracy: {accuracy_nb}")
# Out:
# Accuracy: 0.7889570552147239

# %%
from colorama import Fore, Style

print("Actual  Predicted")
for actual, predicted in zip(results_nb['Actual'], results_nb['Predicted']):
    if actual == predicted:
        print(f"{actual:<8} {predicted:<10}")
    else:
        print(f"{Fore.RED}{actual:<8}{Style.RESET_ALL} {Fore.RED}{predicted:<10}{Style.RESET_ALL}")
# Out:
# Actual  Predicted
# Fake     Fake
# Fake     Fake
# original Fake
# original original
# original Fake
# Fake     Fake
# original Fake
# original Fake
# original Fake
# Fake     Fake
# Fake     Fake
# original Fake
# Fake     original
# Fake     Fake
# Fake     Fake
# original original
# original original
# Fake     Fake
# original original
# Fake     Fake
# original original
# Fake     original
# Fake     Fake
# Fake     Fake
# original original
# original Fake
# Fake     Fake
# Fake     Fake
# original original
# original original
# Fake     Fake
# original original
# original original
# Fake     Fake
# Fake     Fake
# Fake     Fake
# original original
# original Fake
# original original
# Fake     Fake
# Fake     Fake
# original original
# Fake     Fake
# Fake     original
# Fake     Fake
# Fake     Fake
# Fake     Fake
# Fake     Fake
# Fake     Fake
# Fake     Fake
# original original
# original original
# Fake     Fake
# Fake     Fake
# original original
# original original
# original Fake
# Fake     Fake
# original original
# original original
# original original
# Fake     original
# original Fake
# original original
# Fake     Fake
# Fake     Fake
# original Fake
# original original
# Fake     Fake
# Fake     Fake
# original original
# original original
# original original
# Fake     Fake
# Fake     Fake
# Fake     Fake
# Fake     Fake
# original Fake
# Fake     original
# Fake     Fake
# original original
# original original
# Fake     original
# original Fake
# original original
# original original
# original original
# Fake     Fake
# Fake     Fake
# Fake     Fake
# Fake     Fake
# Fake     original
# original original
# original original
# Fake     Fake
# Fake     original
# Fake     original
# original original
# original original
# Fake     Fake
# original original
# Fake     Fake
# original original
# Fake     Fake
# Fake     Fake
# Fake     Fake
# original original
# Fake     Fake
# Fake     Fake
# Fake     Fake
# Fake     original
# Fake     Fake
# original Fake
# original original
# original original
# Fake     Fake
# original original
# original original
# original original
# original Fake
# Fake     original
# original original
# Fake     Fake
# original original
# Fake     Fake
# original Fake
# Fake     Fake
# original original
# Fake     Fake
# Fake     Fake
# Fake     Fake
# original original
# Fake     Fake
# original original
# original original
# Fake     Fake
# Fake     original
# original original
# Fake     original
# Fake     Fake
# original original
# original original
# Fake     Fake
# original original
# Fake     original
# Fake     Fake
# original Fake
# Fake     Fake
# Fake     Fake
# original original
# original original
# Fake     Fake
# Fake     Fake
# original original
# original original
# original original
# Fake     Fake
# Fake     Fake
# Fake     Fake
# Fake     Fake
# original Fake
# original Fake
# original Fake
# original Fake
# Fake     Fake
# Fake     Fake
# Fake     Fake
# original original
# Fake     Fake
# Fake     Fake
# Fake     Fake
# original Fake
# Fake     original
# Fake     Fake
# original original
# Fake     Fake
# Fake     original
# original original
# Fake     original
# Fake     Fake
# original original
# original original
# original original
# original original
# Fake     Fake
# original Fake
# original original
# Fake     Fake
# Fake     Fake
# original original
# original Fake
# original original
# original original
# Fake     Fake
# original original
# original original
# Fake     Fake
# Fake     Fake
# original original
# original original
# original original
# Fake     original
# original original
# Fake     original
# Fake     Fake
# Fake     Fake
# original original
# Fake     Fake
# Fake     original
# original original
# original original
# original original
# Fake     Fake
# Fake     Fake
# original Fake
# original original
# Fake     Fake
# original original
# original original
# Fake     Fake
# original original
# Fake     Fake
# original original
# original original
# Fake     Fake
# original original
# Fake     Fake
# original original
# Fake     Fake
# Fake     Fake
# original Fake
# original original
# original original
# Fake     Fake
# original original
# Fake     Fake
# Fake     Fake
# original Fake
# Fake     Fake
# original original
# Fake     Fake
# original original
# original original
# Fake     Fake
# Fake     original
# original original
# original original
# original original
# original original
# original original
# original Fake
# Fake     Fake
# Fake     Fake
# original Fake
# Fake     Fake
# Fake     Fake
# Fake     Fake
# Fake     Fake
# original original
# original original
# original Fake
# original original
# original original
# original original
# original Fake
# Fake     Fake
# Fake     Fake
# original Fake
# Fake     Fake
# original original
# original original
# Fake     Fake
# original original
# original original
# Fake     Fake
# original Fake
# original Fake
# Fake     Fake
# original original
# original Fake
# Fake     original
# Fake     original
# Fake     Fake
# original Fake
# original original
# Fake     original
# Fake     Fake
# Fake     original
# Fake     Fake
# Fake     Fake
# Fake     Fake
# Fake     original
# original Fake
# Fake     original
# Fake     Fake
# Fake     Fake
# Fake     original
# Fake     Fake
# Fake     Fake
# original original
# original original
# original original
# Fake     Fake
# Fake     Fake
# Fake     Fake
# Fake     original
# original original
# original original
# original original
# Fake     Fake
# original Fake
# original original
# original Fake
# original original
# original original
# original Fake
# Fake     Fake
# original original
# Fake     Fake
# original Fake
# Fake     Fake
# Fake     original
# original original
# Fake     Fake
# Fake     Fake
# original original
# original original
# original original
# Fake     Fake
# original original
# Fake     Fake
# Fake     original
# Fake     Fake
# Fake     original
# Fake     original
# original original
# Fake     Fake
# original original
# Fake     Fake
# Fake     original
# original original
# Fake     Fake
# Fake     Fake
# Fake     Fake
# original Fake
# Fake     Fake
# original original
# Fake     Fake
# Fake     Fake
# Fake     Fake
# original original
# Fake     Fake
# Fake     Fake
# original original
# original original
# Fake     Fake
# Fake     Fake
# original original
# original original
# original original
# Fake     Fake
# Fake     original
# Fake     Fake
# Fake     Fake
# original original
# original original
# Fake     original
# original original
# original original
# Fake     Fake
# Fake     Fake
# Fake     Fake
# original Fake
# Fake     Fake
# original original
# Fake     Fake
# Fake     original
# original original
# original original
# original original
# original original
# original original
# Fake     Fake
# Fake     Fake
# Fake     original
# original original
# original original
# original original
# original Fake
# Fake     original
# Fake     Fake
# Fake     original
# Fake     Fake
# Fake     original
# original original
# Fake     Fake
# Fake     Fake
# original original
# original original
# original original
# original Fake
# original Fake
# Fake     Fake
# Fake     Fake
# original original
# original original
# Fake     original
# original original
# Fake     original
# Fake     Fake
# original original
# original original
# original Fake
# Fake     Fake
# original original
# original original
# Fake     Fake
# Fake     Fake
# Fake     Fake
# Fake     Fake
# original original
# original Fake
# original original
# Fake     Fake
# original original
# original original
# original original
# original Fake
# Fake     Fake
# original original
# Fake     Fake
# original original
# Fake     Fake
# original original
# original original
# Fake     Fake
# original original
# original Fake
# original original
# original original
# Fake     Fake
# original original
# original original
# original original
# original original
# original original
# original Fake
# original original
# original original
# Fake     Fake
# Fake     Fake
# original original
# original original
# Fake     Fake
# Fake     Fake
# original original
# Fake     Fake
# original original
# Fake     Fake
# original original
# Fake     Fake
# Fake     Fake
# Fake     Fake
# original Fake
# Fake     original
# original original
# Fake     Fake
# Fake     Fake
# Fake     Fake
# original original
# Fake     Fake
# Fake     original
# Fake     Fake
# Fake     Fake
# Fake     Fake
# original original
# original Fake
# Fake     Fake
# original original
# original Fake
# original original
# original original
# Fake     Fake
# original original
# original original
# Fake     original
# Fake     Fake
# Fake     original
# Fake     Fake
# original original
# original original
# Fake     Fake
# Fake     Fake
# Fake     Fake
# Fake     original
# original original
# original original
# original original
# Fake     Fake
# Fake     Fake
# original original
# original Fake
# original Fake
# Fake     Fake
# Fake     Fake
# original original
# Fake     original
# Fake     original
# Fake     Fake
# Fake     Fake
# original original
# original original
# original original
# original original
# original original
# Fake     Fake
# original original
# original original
# Fake     Fake
# original Fake
# original Fake
# Fake     Fake
# Fake     Fake
# Fake     Fake
# Fake     original
# Fake     Fake
# original original
# Fake     original
# original Fake
# Fake     Fake
# Fake     Fake
# original Fake
# Fake     Fake
# Fake     original
# original original
# Fake     Fake
# original original
# Fake     Fake
# original original
# original original
# original original
# Fake     Fake
# original original
# original original
# original original
# Fake     Fake
# original original
# Fake     Fake
# Fake     original
# original Fake
# Fake     original
# Fake     original
# original original
# original original
# Fake     original
# original original
# Fake     Fake
# original original
# Fake     original
# original original
# Fake     original
# Fake     Fake
# Fake     Fake
# original original
# Fake     original
# original original
# Fake     Fake
# original original
# Fake     Fake
# Fake     original
# original original
# original original
# original original
# Fake     Fake
# Fake     Fake
# original Fake
# original original
# Fake     Fake
# Fake     Fake
# Fake     Fake
# Fake     Fake
# original Fake
# Fake     original
# original original
# Fake     Fake
# Fake     Fake
# original Fake
# original original
# Fake     Fake
# Fake     Fake
# Fake     original
# original original
# original original
# Fake     Fake
# original original
# Fake     Fake
# Fake     original
# Fake     original
# Fake     Fake
# original original
# Fake     Fake
# Fake     Fake
# original Fake
# original original
# Fake     Fake
# Fake     Fake
# original original
# Fake     Fake
# Fake     Fake
# original original
# Fake     Fake
# original original
# Fake     Fake
# Fake     original
# Fake     Fake
# Fake     Fake
# original original
# Fake     Fake
# original original
# Fake     Fake
# original Fake
# Fake     Fake
# Fake     Fake
# Fake     Fake
# Fake     Fake
# Fake     original
# Fake     original
# original original
# original Fake
# original original
# Fake     Fake
# original original
# original original
# original original
# original original
# original original
# original original
# Fake     Fake
# original original
# original Fake
# original Fake
# Fake     Fake
# original original
# Fake     Fake
# original original
# original original
# Fake     Fake
# original original
# Fake     Fake
# original Fake
# Fake     Fake
# Fake     Fake
# original original
# original original
# original original
# original original
# original Fake
# Fake     Fake
# original original
# Fake     original
# original original
# Fake     original
# original original
# original original
# original original
# original original
# original Fake
# Fake     Fake
# original original
# original Fake
# original original
# original original
# original original
# Fake     original
# Fake     Fake
# original original
# original original
# Fake     original
# Fake     Fake
# original original
# original original
# original Fake
# Fake     Fake
# original original
# original original
# original original
# original original
# Fake     Fake
# Fake     Fake
# Fake     Fake
# original Fake
# Fake     Fake
# Fake     Fake
# original Fake
# original Fake
# original original
# original original
# Fake     Fake
# original original
# original original
# original Fake
# original Fake
# Fake     Fake
# Fake     Fake
# Fake     original
# Fake     Fake
# original original
# original original
# Fake     Fake
# original original
# Fake     Fake
# original original
# Fake     original
# original original
# original Fake
# original original
# Fake     original
# Fake     Fake
# original original
# original original
# original original
# original original
# original original
# original original
# original original
# Fake     Fake
# Fake     Fake
# Fake     Fake
# original original
# Fake     Fake
# Fake     Fake
# original original
# original original
# original original
# original original
# Fake     Fake
# Fake     Fake
# original original
# Fake     Fake
# original original
# Fake     Fake
# original original
# Fake     Fake
# Fake     Fake
# original original
# original original
# original Fake
# Fake     original
# original original
# Fake     Fake
# original original
# Fake     Fake
# Fake     Fake
# Fake     Fake
# Fake     Fake
# Fake     Fake
# original original
# Fake     Fake
# original original
# Fake     Fake
# Fake     original
# Fake     original
# Fake     Fake
# Fake     Fake
# original original
# Fake     original
# Fake     Fake
# original Fake
# original original
# Fake     Fake
# Fake     Fake
# original original
# Fake     original
# original original
# original Fake
# Fake     Fake
# Fake     original
# Fake     Fake
# Fake     Fake
# original original
# Fake     Fake
# original original
# original original
# original Fake
# original original
# Fake     Fake
# original original
# Fake     original
# Fake     original
# original Fake
# Fake     original
# original Fake
# Fake     Fake
# original original
# Fake     Fake
# Fake     Fake
# Fake     Fake
# Fake     Fake
# Fake     Fake
# original original
# Fake     Fake
# Fake     Fake
# original Fake
# Fake     Fake
# original original
# original original
# original original
# Fake     Fake
# original original
# original original
# original original
# original original
# Fake     Fake
# Fake     original
# original original

# %% [markdown]
# ### SVM

# %%
classifier_svm = SVC(kernel='rbf')
classifier_svm.fit(X_train, y_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
# Predict on the development set
predictions_svm = classifier_svm.predict(X_dev)

# %%
results_svm = pd.DataFrame({
    'Text': fake_dev['text'],
    'Actual': y_dev,
    'Predicted': predictions_svm
})

# %%
# Calculate the accuracy
accuracy_svm = accuracy_score(y_dev, predictions_svm)
print(f"Accuracy: {accuracy_svm}")
# Out:
# Accuracy: 0.501840490797546

# %%
print("Actual  Predicted")
for actual, predicted in zip(results_svm['Actual'], results_svm['Predicted']):
    if actual == predicted:
        print(f"{actual:<8} {predicted:<10}")
    else:
        print(f"{Fore.RED}{actual:<8}{Style.RESET_ALL} {Fore.RED}{predicted:<10}{Style.RESET_ALL}")
# Out:
# Actual  Predicted
# Fake     original
# Fake     original
# original original
# original original
# original original
# Fake     original
# original original
# original original
# original original
# Fake     original
# Fake     original
# original original
# Fake     original
# Fake     original
# Fake     original
# original original
# original original
# Fake     original
# original original
# Fake     original
# original original
# Fake     original
# Fake     original
# Fake     original
# original original
# original original
# Fake     original
# Fake     original
# original original
# original original
# Fake     original
# original original
# original original
# Fake     original
# Fake     original
# Fake     original
# original original
# original original
# original original
# Fake     original
# Fake     original
# original original
# Fake     original
# Fake     original
# Fake     original
# Fake     original
# Fake     original
# Fake     original
# Fake     original
# Fake     original
# original original
# original original
# Fake     original
# Fake     original
# original original
# original original
# original original
# Fake     original
# original original
# original original
# original original
# Fake     original
# original original
# original original
# Fake     original
# Fake     original
# original original
# original original
# Fake     original
# Fake     original
# original original
# original original
# original original
# Fake     original
# Fake     original
# Fake     original
# Fake     original
# original original
# Fake     original
# Fake     original
# original original
# original original
# Fake     original
# original original
# original original
# original original
# original original
# Fake     original
# Fake     original
# Fake     original
# Fake     original
# Fake     original
# original original
# original original
# Fake     original
# Fake     original
# Fake     original
# original original
# original original
# Fake     original
# original original
# Fake     original
# original original
# Fake     original
# Fake     original
# Fake     original
# original original
# Fake     original
# Fake     original
# Fake     original
# Fake     original
# Fake     original
# original original
# original original
# original original
# Fake     original
# original original
# original original
# original original
# original original
# Fake     original
# original original
# Fake     original
# original original
# Fake     original
# original original
# Fake     original
# original original
# Fake     original
# Fake     original
# Fake     original
# original original
# Fake     original
# original original
# original original
# Fake     original
# Fake     original
# original original
# Fake     original
# Fake     original
# original original
# original original
# Fake     original
# original original
# Fake     original
# Fake     original
# original original
# Fake     original
# Fake     original
# original original
# original original
# Fake     original
# Fake     original
# original original
# original original
# original original
# Fake     original
# Fake     original
# Fake     original
# Fake     original
# original original
# original original
# original original
# original original
# Fake     original
# Fake     original
# Fake     original
# original original
# Fake     original
# Fake     original
# Fake     original
# original original
# Fake     original
# Fake     original
# original original
# Fake     original
# Fake     original
# original original
# Fake     original
# Fake     original
# original original
# original original
# original original
# original original
# Fake     original
# original original
# original original
# Fake     original
# Fake     original
# original original
# original original
# original original
# original original
# Fake     original
# original original
# original original
# Fake     original
# Fake     original
# original original
# original original
# original original
# Fake     original
# original original
# Fake     original
# Fake     original
# Fake     original
# original original
# Fake     original
# Fake     original
# original original
# original original
# original original
# Fake     original
# Fake     original
# original original
# original original
# Fake     original
# original original
# original original
# Fake     original
# original original
# Fake     original
# original original
# original original
# Fake     original
# original original
# Fake     original
# original original
# Fake     original
# Fake     original
# original original
# original original
# original original
# Fake     original
# original original
# Fake     original
# Fake     original
# original original
# Fake     original
# original original
# Fake     original
# original original
# original original
# Fake     original
# Fake     original
# original original
# original original
# original original
# original original
# original original
# original original
# Fake     original
# Fake     original
# original original
# Fake     original
# Fake     original
# Fake     original
# Fake     original
# original original
# original original
# original original
# original original
# original original
# original original
# original original
# Fake     original
# Fake     original
# original original
# Fake     original
# original original
# original original
# Fake     original
# original original
# original original
# Fake     original
# original original
# original original
# Fake     original
# original original
# original original
# Fake     original
# Fake     original
# Fake     original
# original original
# original original
# Fake     original
# Fake     original
# Fake     original
# Fake     original
# Fake     original
# Fake     original
# Fake     original
# original original
# Fake     original
# Fake     original
# Fake     original
# Fake     original
# Fake     original
# Fake     original
# original original
# original original
# original original
# Fake     original
# Fake     original
# Fake     original
# Fake     original
# original original
# original original
# original original
# Fake     original
# original original
# original original
# original original
# original original
# original original
# original original
# Fake     original
# original original
# Fake     original
# original original
# Fake     original
# Fake     original
# original original
# Fake     original
# Fake     original
# original original
# original original
# original original
# Fake     original
# original original
# Fake     original
# Fake     original
# Fake     original
# Fake     original
# Fake     original
# original original
# Fake     original
# original original
# Fake     original
# Fake     original
# original original
# Fake     original
# Fake     original
# Fake     original
# original original
# Fake     original
# original original
# Fake     original
# Fake     original
# Fake     original
# original original
# Fake     original
# Fake     original
# original original
# original original
# Fake     original
# Fake     original
# original original
# original original
# original original
# Fake     original
# Fake     original
# Fake     original
# Fake     original
# original original
# original original
# Fake     original
# original original
# original original
# Fake     original
# Fake     original
# Fake     original
# original original
# Fake     original
# original original
# Fake     original
# Fake     original
# original original
# original original
# original original
# original original
# original original
# Fake     original
# Fake     original
# Fake     original
# original original
# original original
# original original
# original original
# Fake     original
# Fake     original
# Fake     original
# Fake     original
# Fake     original
# original original
# Fake     original
# Fake     original
# original original
# original original
# original original
# original original
# original original
# Fake     original
# Fake     original
# original original
# original original
# Fake     original
# original original
# Fake     original
# Fake     original
# original original
# original original
# original original
# Fake     original
# original original
# original original
# Fake     original
# Fake     original
# Fake     original
# Fake     original
# original original
# original original
# original original
# Fake     original
# original original
# original original
# original original
# original original
# Fake     original
# original original
# Fake     original
# original original
# Fake     original
# original original
# original original
# Fake     original
# original original
# original original
# original original
# original original
# Fake     original
# original original
# original original
# original original
# original original
# original original
# original original
# original original
# original original
# Fake     original
# Fake     original
# original original
# original original
# Fake     original
# Fake     original
# original original
# Fake     original
# original original
# Fake     original
# original original
# Fake     original
# Fake     original
# Fake     original
# original original
# Fake     original
# original original
# Fake     original
# Fake     original
# Fake     original
# original original
# Fake     original
# Fake     original
# Fake     original
# Fake     original
# Fake     original
# original original
# original original
# Fake     original
# original original
# original original
# original original
# original original
# Fake     original
# original original
# original original
# Fake     original
# Fake     original
# Fake     original
# Fake     original
# original original
# original original
# Fake     original
# Fake     original
# Fake     original
# Fake     original
# original original
# original original
# original original
# Fake     original
# Fake     original
# original original
# original original
# original original
# Fake     original
# Fake     original
# original original
# Fake     original
# Fake     original
# Fake     original
# Fake     original
# original original
# original original
# original original
# original original
# original original
# Fake     original
# original original
# original original
# Fake     original
# original original
# original original
# Fake     original
# Fake     original
# Fake     original
# Fake     original
# Fake     original
# original original
# Fake     original
# original original
# Fake     original
# Fake     original
# original original
# Fake     original
# Fake     original
# original original
# Fake     original
# original original
# Fake     original
# original original
# original original
# original original
# Fake     original
# original original
# original original
# original original
# Fake     original
# original original
# Fake     original
# Fake     original
# original original
# Fake     original
# Fake     original
# original original
# original original
# Fake     original
# original original
# Fake     original
# original original
# Fake     original
# original original
# Fake     original
# Fake     original
# Fake     original
# original original
# Fake     original
# original original
# Fake     original
# original original
# Fake     original
# Fake     original
# original original
# original original
# original original
# Fake     original
# Fake     original
# original original
# original original
# Fake     original
# Fake     original
# Fake     original
# Fake     original
# original original
# Fake     original
# original original
# Fake     original
# Fake     original
# original original
# original original
# Fake     original
# Fake     original
# Fake     original
# original original
# original original
# Fake     original
# original original
# Fake     original
# Fake     original
# Fake     original
# Fake     original
# original original
# Fake     original
# Fake     original
# original original
# original original
# Fake     original
# Fake     original
# original original
# Fake     original
# Fake     original
# original original
# Fake     original
# original original
# Fake     original
# Fake     original
# Fake     original
# Fake     original
# original original
# Fake     original
# original original
# Fake     original
# original original
# Fake     original
# Fake     original
# Fake     original
# Fake     original
# Fake     original
# Fake     original
# original original
# original original
# original original
# Fake     original
# original original
# original original
# original original
# original original
# original original
# original original
# Fake     original
# original original
# original original
# original original
# Fake     original
# original original
# Fake     original
# original original
# original original
# Fake     original
# original original
# Fake     original
# original original
# Fake     original
# Fake     original
# original original
# original original
# original original
# original original
# original original
# Fake     original
# original original
# Fake     original
# original original
# Fake     original
# original original
# original original
# original original
# original original
# original original
# Fake     original
# original original
# original original
# original original
# original original
# original original
# Fake     original
# Fake     original
# original original
# original original
# Fake     original
# Fake     original
# original original
# original original
# original original
# Fake     original
# original original
# original original
# original original
# original original
# Fake     original
# Fake     original
# Fake     original
# original original
# Fake     original
# Fake     original
# original original
# original original
# original original
# original original
# Fake     original
# original original
# original original
# original original
# original original
# Fake     original
# Fake     original
# Fake     original
# Fake     original
# original original
# original original
# Fake     original
# original original
# Fake     original
# original original
# Fake     original
# original original
# original original
# original original
# Fake     original
# Fake     original
# original original
# original original
# original original
# original original
# original original
# original original
# original original
# Fake     original
# Fake     original
# Fake     original
# original original
# Fake     original
# Fake     original
# original original
# original original
# original original
# original original
# Fake     original
# Fake     original
# original original
# Fake     original
# original original
# Fake     original
# original original
# Fake     original
# Fake     original
# original original
# original original
# original original
# Fake     original
# original original
# Fake     original
# original original
# Fake     original
# Fake     original
# Fake     original
# Fake     original
# Fake     original
# original original
# Fake     original
# original original
# Fake     original
# Fake     original
# Fake     original
# Fake     original
# Fake     original
# original original
# Fake     original
# Fake     original
# original original
# original original
# Fake     original
# Fake     original
# original original
# Fake     original
# original original
# original original
# Fake     original
# Fake     original
# Fake     original
# Fake     original
# original original
# Fake     original
# original original
# original original
# original original
# original original
# Fake     original
# original original
# Fake     original
# Fake     original
# original original
# Fake     original
# original original
# Fake     original
# original original
# Fake     original
# Fake     original
# Fake     original
# Fake     original
# Fake     original
# original original
# Fake     original
# Fake     original
# original original
# Fake     original
# original original
# original original
# original original
# Fake     original
# original original
# original original
# original original
# original original
# Fake     original
# Fake     original
# original original

# %% [markdown]
# ### Random Forest

# %%
param_grid = {'n_estimators': [50, 100, 200],
              'max_depth': [None, 10, 20, 30],
              'min_samples_split': [2, 5, 10],
              'min_samples_leaf': [1, 2, 4]}

# %%
classifier = RandomForestClassifier(random_state=42)
grid_search = GridSearchCV(classifier, param_grid, cv=5, scoring='accuracy', n_jobs=-1)
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, error_score='raise',
#        estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=10, n_jobs=1, oob_score=False, random_state=42,
#             verbose=0, warm_start=False),
#        fit_params={}, iid=True, n_jobs=-1,
#        param_grid={'n_estimators': [50, 100, 200], 'max_depth': [None, 10, 20, 30], 'min_samples_split': [2, 5, 10], 'min_samples_leaf': [1, 2, 4]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring='accuracy', verbose=0)

# %%
# Predict on the development set
best_classifier_rf = grid_search.best_estimator_
predictions_rf = best_classifier_rf.predict(X_dev)

# %%
results_rf = pd.DataFrame({
    'Text': fake_dev['text'],
    'Actual': y_dev,
    'Predicted': predictions_rf
})

# %%
# Calculate the accuracy
accuracy_rf = accuracy_score(y_dev, predictions_rf)
print(f"Accuracy: {accuracy_rf}")
# Out:
# Accuracy: 0.7558282208588957

# %%
print("Actual  Predicted")
for actual, predicted in zip(results_rf['Actual'], results_rf['Predicted']):
    if actual == predicted:
        print(f"{actual:<8} {predicted:<10}")
    else:
        print(f"{Fore.RED}{actual:<8}{Style.RESET_ALL} {Fore.RED}{predicted:<10}{Style.RESET_ALL}")
# Out:
# Actual  Predicted
# Fake     original
# Fake     Fake
# original Fake
# original original
# original Fake
# Fake     original
# original Fake
# original original
# original Fake
# Fake     Fake
# Fake     Fake
# original Fake
# Fake     original
# Fake     Fake
# Fake     Fake
# original original
# original original
# Fake     Fake
# original original
# Fake     Fake
# original original
# Fake     original
# Fake     original
# Fake     Fake
# original original
# original original
# Fake     Fake
# Fake     Fake
# original original
# original original
# Fake     Fake
# original original
# original original
# Fake     Fake
# Fake     Fake
# Fake     original
# original original
# original original
# original original
# Fake     original
# Fake     Fake
# original original
# Fake     original
# Fake     Fake
# Fake     Fake
# Fake     Fake
# Fake     Fake
# Fake     Fake
# Fake     Fake
# Fake     Fake
# original original
# original original
# Fake     original
# Fake     Fake
# original original
# original original
# original original
# Fake     Fake
# original original
# original original
# original original
# Fake     original
# original original
# original original
# Fake     original
# Fake     Fake
# original original
# original original
# Fake     Fake
# Fake     Fake
# original original
# original original
# original original
# Fake     Fake
# Fake     Fake
# Fake     Fake
# Fake     Fake
# original original
# Fake     original
# Fake     Fake
# original original
# original original
# Fake     original
# original Fake
# original original
# original original
# original original
# Fake     Fake
# Fake     Fake
# Fake     original
# Fake     original
# Fake     original
# original original
# original original
# Fake     original
# Fake     original
# Fake     original
# original original
# original original
# Fake     Fake
# original original
# Fake     original
# original original
# Fake     Fake
# Fake     Fake
# Fake     Fake
# original original
# Fake     original
# Fake     original
# Fake     original
# Fake     original
# Fake     Fake
# original Fake
# original original
# original original
# Fake     Fake
# original original
# original original
# original original
# original original
# Fake     original
# original original
# Fake     Fake
# original original
# Fake     Fake
# original original
# Fake     Fake
# original original
# Fake     Fake
# Fake     Fake
# Fake     Fake
# original original
# Fake     Fake
# original original
# original original
# Fake     Fake
# Fake     original
# original original
# Fake     original
# Fake     Fake
# original original
# original original
# Fake     Fake
# original original
# Fake     original
# Fake     Fake
# original original
# Fake     Fake
# Fake     original
# original original
# original original
# Fake     Fake
# Fake     Fake
# original original
# original original
# original original
# Fake     original
# Fake     original
# Fake     Fake
# Fake     Fake
# original original
# original original
# original original
# original Fake
# Fake     Fake
# Fake     Fake
# Fake     Fake
# original Fake
# Fake     Fake
# Fake     Fake
# Fake     Fake
# original original
# Fake     original
# Fake     Fake
# original original
# Fake     Fake
# Fake     Fake
# original original
# Fake     original
# Fake     Fake
# original original
# original original
# original Fake
# original original
# Fake     Fake
# original original
# original original
# Fake     Fake
# Fake     Fake
# original original
# original Fake
# original original
# original original
# Fake     Fake
# original original
# original original
# Fake     original
# Fake     Fake
# original original
# original original
# original original
# Fake     original
# original original
# Fake     original
# Fake     original
# Fake     Fake
# original Fake
# Fake     Fake
# Fake     Fake
# original Fake
# original original
# original original
# Fake     original
# Fake     original
# original Fake
# original Fake
# Fake     Fake
# original original
# original original
# Fake     Fake
# original original
# Fake     Fake
# original original
# original original
# Fake     Fake
# original original
# Fake     Fake
# original original
# Fake     original
# Fake     Fake
# original Fake
# original original
# original original
# Fake     original
# original original
# Fake     Fake
# Fake     Fake
# original original
# Fake     Fake
# original original
# Fake     original
# original original
# original original
# Fake     Fake
# Fake     original
# original original
# original original
# original original
# original original
# original original
# original original
# Fake     Fake
# Fake     Fake
# original Fake
# Fake     Fake
# Fake     Fake
# Fake     Fake
# Fake     Fake
# original Fake
# original original
# original original
# original original
# original original
# original original
# original original
# Fake     Fake
# Fake     Fake
# original Fake
# Fake     Fake
# original original
# original original
# Fake     Fake
# original original
# original Fake
# Fake     Fake
# original Fake
# original original
# Fake     Fake
# original original
# original original
# Fake     Fake
# Fake     Fake
# Fake     Fake
# original Fake
# original original
# Fake     original
# Fake     original
# Fake     Fake
# Fake     Fake
# Fake     Fake
# Fake     Fake
# Fake     original
# original Fake
# Fake     original
# Fake     Fake
# Fake     Fake
# Fake     original
# Fake     Fake
# Fake     Fake
# original original
# original original
# original original
# Fake     Fake
# Fake     Fake
# Fake     original
# Fake     original
# original original
# original original
# original Fake
# Fake     Fake
# original Fake
# original original
# original Fake
# original original
# original Fake
# original Fake
# Fake     Fake
# original original
# Fake     Fake
# original original
# Fake     Fake
# Fake     original
# original original
# Fake     Fake
# Fake     Fake
# original original
# original original
# original Fake
# Fake     Fake
# original original
# Fake     Fake
# Fake     original
# Fake     Fake
# Fake     original
# Fake     original
# original original
# Fake     Fake
# original original
# Fake     original
# Fake     original
# original original
# Fake     original
# Fake     Fake
# Fake     Fake
# original original
# Fake     Fake
# original original
# Fake     Fake
# Fake     Fake
# Fake     original
# original original
# Fake     original
# Fake     original
# original original
# original Fake
# Fake     Fake
# Fake     original
# original original
# original original
# original original
# Fake     Fake
# Fake     original
# Fake     Fake
# Fake     Fake
# original original
# original original
# Fake     original
# original original
# original original
# Fake     Fake
# Fake     Fake
# Fake     Fake
# original Fake
# Fake     Fake
# original original
# Fake     original
# Fake     original
# original original
# original original
# original original
# original original
# original original
# Fake     Fake
# Fake     Fake
# Fake     original
# original original
# original original
# original original
# original Fake
# Fake     original
# Fake     original
# Fake     original
# Fake     Fake
# Fake     original
# original original
# Fake     Fake
# Fake     Fake
# original original
# original original
# original original
# original original
# original Fake
# Fake     Fake
# Fake     Fake
# original original
# original original
# Fake     Fake
# original original
# Fake     Fake
# Fake     Fake
# original original
# original original
# original Fake
# Fake     Fake
# original original
# original original
# Fake     Fake
# Fake     Fake
# Fake     Fake
# Fake     Fake
# original original
# original Fake
# original original
# Fake     Fake
# original Fake
# original original
# original original
# original Fake
# Fake     Fake
# original original
# Fake     Fake
# original original
# Fake     Fake
# original original
# original original
# Fake     Fake
# original original
# original original
# original original
# original original
# Fake     original
# original original
# original original
# original original
# original Fake
# original original
# original original
# original Fake
# original Fake
# Fake     Fake
# Fake     Fake
# original original
# original original
# Fake     Fake
# Fake     Fake
# original original
# Fake     Fake
# original original
# Fake     original
# original original
# Fake     Fake
# Fake     Fake
# Fake     Fake
# original original
# Fake     Fake
# original original
# Fake     Fake
# Fake     Fake
# Fake     Fake
# original original
# Fake     Fake
# Fake     original
# Fake     Fake
# Fake     Fake
# Fake     Fake
# original Fake
# original original
# Fake     Fake
# original original
# original Fake
# original original
# original original
# Fake     Fake
# original original
# original original
# Fake     original
# Fake     Fake
# Fake     original
# Fake     Fake
# original original
# original original
# Fake     original
# Fake     Fake
# Fake     Fake
# Fake     original
# original original
# original Fake
# original original
# Fake     Fake
# Fake     Fake
# original original
# original original
# original Fake
# Fake     Fake
# Fake     original
# original original
# Fake     original
# Fake     original
# Fake     Fake
# Fake     Fake
# original original
# original original
# original Fake
# original original
# original Fake
# Fake     Fake
# original original
# original original
# Fake     Fake
# original Fake
# original Fake
# Fake     Fake
# Fake     Fake
# Fake     Fake
# Fake     original
# Fake     Fake
# original original
# Fake     original
# original original
# Fake     Fake
# Fake     Fake
# original Fake
# Fake     Fake
# Fake     original
# original original
# Fake     Fake
# original original
# Fake     Fake
# original original
# original original
# original original
# Fake     Fake
# original original
# original original
# original original
# Fake     Fake
# original original
# Fake     Fake
# Fake     original
# original Fake
# Fake     original
# Fake     original
# original original
# original original
# Fake     Fake
# original original
# Fake     Fake
# original original
# Fake     original
# original original
# Fake     original
# Fake     Fake
# Fake     original
# original original
# Fake     Fake
# original original
# Fake     Fake
# original original
# Fake     Fake
# Fake     Fake
# original original
# original original
# original original
# Fake     Fake
# Fake     Fake
# original original
# original original
# Fake     Fake
# Fake     Fake
# Fake     Fake
# Fake     Fake
# original original
# Fake     Fake
# original original
# Fake     Fake
# Fake     Fake
# original Fake
# original original
# Fake     Fake
# Fake     original
# Fake     original
# original original
# original original
# Fake     original
# original original
# Fake     Fake
# Fake     original
# Fake     original
# Fake     Fake
# original original
# Fake     Fake
# Fake     original
# original Fake
# original original
# Fake     Fake
# Fake     Fake
# original original
# Fake     original
# Fake     Fake
# original original
# Fake     Fake
# original original
# Fake     Fake
# Fake     original
# Fake     Fake
# Fake     Fake
# original Fake
# Fake     Fake
# original original
# Fake     Fake
# original Fake
# Fake     Fake
# Fake     Fake
# Fake     Fake
# Fake     Fake
# Fake     original
# Fake     original
# original original
# original Fake
# original original
# Fake     Fake
# original original
# original original
# original original
# original original
# original original
# original original
# Fake     Fake
# original original
# original original
# original original
# Fake     Fake
# original original
# Fake     original
# original original
# original Fake
# Fake     Fake
# original Fake
# Fake     Fake
# original original
# Fake     Fake
# Fake     Fake
# original original
# original original
# original original
# original original
# original original
# Fake     Fake
# original original
# Fake     Fake
# original original
# Fake     original
# original original
# original original
# original original
# original original
# original original
# Fake     original
# original original
# original Fake
# original original
# original original
# original original
# Fake     original
# Fake     Fake
# original Fake
# original original
# Fake     original
# Fake     original
# original original
# original original
# original Fake
# Fake     original
# original original
# original original
# original original
# original original
# Fake     original
# Fake     Fake
# Fake     Fake
# original Fake
# Fake     Fake
# Fake     Fake
# original original
# original Fake
# original original
# original original
# Fake     Fake
# original Fake
# original original
# original Fake
# original original
# Fake     Fake
# Fake     Fake
# Fake     original
# Fake     Fake
# original original
# original original
# Fake     Fake
# original original
# Fake     Fake
# original original
# Fake     original
# original original
# original original
# original original
# Fake     original
# Fake     original
# original original
# original Fake
# original original
# original original
# original original
# original original
# original original
# Fake     Fake
# Fake     Fake
# Fake     Fake
# original original
# Fake     Fake
# Fake     Fake
# original original
# original Fake
# original original
# original original
# Fake     Fake
# Fake     original
# original original
# Fake     Fake
# original original
# Fake     Fake
# original original
# Fake     original
# Fake     Fake
# original Fake
# original original
# original Fake
# Fake     original
# original original
# Fake     Fake
# original original
# Fake     original
# Fake     Fake
# Fake     Fake
# Fake     Fake
# Fake     Fake
# original original
# Fake     Fake
# original original
# Fake     original
# Fake     original
# Fake     original
# Fake     Fake
# Fake     Fake
# original Fake
# Fake     original
# Fake     Fake
# original original
# original original
# Fake     Fake
# Fake     Fake
# original original
# Fake     original
# original original
# original original
# Fake     original
# Fake     original
# Fake     Fake
# Fake     original
# original original
# Fake     Fake
# original original
# original original
# original original
# original original
# Fake     Fake
# original original
# Fake     original
# Fake     original
# original Fake
# Fake     original
# original original
# Fake     Fake
# original original
# Fake     Fake
# Fake     Fake
# Fake     original
# Fake     Fake
# Fake     Fake
# original original
# Fake     Fake
# Fake     Fake
# original original
# Fake     Fake
# original original
# original original
# original original
# Fake     Fake
# original original
# original Fake
# original original
# original original
# Fake     Fake
# Fake     original
# original original

# %% [markdown]
# ### Logistic Regression

# %%
param_grid_lr = {'C': [0.001, 0.01, 0.1, 1, 10, 100],
              'solver': ['liblinear', 'lbfgs', 'newton-cg', 'sag']}

# %%
classifier_lr = LogisticRegression(max_iter=1000, random_state=42)
grid_search_lr = GridSearchCV(classifier_lr, param_grid_lr, cv=5, scoring='accuracy', n_jobs=-1)
grid_search_lr.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, error_score='raise',
#        estimator=LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=1000, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=42, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False),
#        fit_params={}, iid=True, n_jobs=-1,
#        param_grid={'C': [0.001, 0.01, 0.1, 1, 10, 100], 'solver': ['liblinear', 'lbfgs', 'newton-cg', 'sag']},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring='accuracy', verbose=0)

# %%
# Predict on the development set
best_classifier_lr = grid_search_lr.best_estimator_
predictions_lr = best_classifier_lr.predict(X_dev)

# %%
results_lr = pd.DataFrame({
    'Text': fake_dev['text'],
    'Actual': y_dev,
    'Predicted': predictions_lr
})

# %%
# Calculate the accuracy
accuracy_lr = accuracy_score(y_dev, predictions_lr)
print(f"Accuracy: {accuracy_lr}")
# Out:
# Accuracy: 0.7865030674846626

# %%
print("Actual  Predicted")
for actual, predicted in zip(results_lr['Actual'], results_lr['Predicted']):
    if actual == predicted:
        print(f"{actual:<8} {predicted:<10}")
    else:
        print(f"{Fore.RED}{actual:<8}{Style.RESET_ALL} {Fore.RED}{predicted:<10}{Style.RESET_ALL}")
# Out:
# Actual  Predicted
# Fake     Fake
# Fake     Fake
# original Fake
# original Fake
# original Fake
# Fake     original
# original Fake
# original original
# original original
# Fake     Fake
# Fake     Fake
# original Fake
# Fake     original
# Fake     Fake
# Fake     Fake
# original original
# original original
# Fake     Fake
# original original
# Fake     Fake
# original original
# Fake     original
# Fake     Fake
# Fake     Fake
# original original
# original Fake
# Fake     Fake
# Fake     Fake
# original original
# original original
# Fake     Fake
# original original
# original original
# Fake     Fake
# Fake     Fake
# Fake     Fake
# original original
# original original
# original original
# Fake     Fake
# Fake     Fake
# original original
# Fake     original
# Fake     Fake
# Fake     Fake
# Fake     Fake
# Fake     original
# Fake     Fake
# Fake     Fake
# Fake     Fake
# original original
# original original
# Fake     Fake
# Fake     Fake
# original original
# original original
# original original
# Fake     Fake
# original original
# original original
# original original
# Fake     Fake
# original Fake
# original original
# Fake     Fake
# Fake     Fake
# original Fake
# original original
# Fake     Fake
# Fake     Fake
# original original
# original original
# original original
# Fake     Fake
# Fake     Fake
# Fake     Fake
# Fake     Fake
# original Fake
# Fake     original
# Fake     Fake
# original original
# original original
# Fake     original
# original Fake
# original original
# original original
# original original
# Fake     Fake
# Fake     Fake
# Fake     Fake
# Fake     Fake
# Fake     original
# original original
# original original
# Fake     original
# Fake     Fake
# Fake     original
# original original
# original original
# Fake     Fake
# original original
# Fake     Fake
# original original
# Fake     Fake
# Fake     Fake
# Fake     Fake
# original original
# Fake     Fake
# Fake     original
# Fake     Fake
# Fake     original
# Fake     Fake
# original Fake
# original original
# original original
# Fake     Fake
# original original
# original original
# original original
# original original
# Fake     Fake
# original original
# Fake     Fake
# original original
# Fake     Fake
# original Fake
# Fake     Fake
# original original
# Fake     Fake
# Fake     Fake
# Fake     Fake
# original original
# Fake     Fake
# original original
# original original
# Fake     Fake
# Fake     original
# original original
# Fake     original
# Fake     Fake
# original original
# original original
# Fake     Fake
# original original
# Fake     original
# Fake     Fake
# original Fake
# Fake     Fake
# Fake     original
# original original
# original original
# Fake     Fake
# Fake     Fake
# original original
# original original
# original original
# Fake     original
# Fake     Fake
# Fake     Fake
# Fake     Fake
# original Fake
# original original
# original original
# original Fake
# Fake     Fake
# Fake     Fake
# Fake     Fake
# original Fake
# Fake     Fake
# Fake     Fake
# Fake     Fake
# original Fake
# Fake     original
# Fake     Fake
# original original
# Fake     Fake
# Fake     Fake
# original original
# Fake     original
# Fake     Fake
# original original
# original Fake
# original original
# original original
# Fake     Fake
# original Fake
# original original
# Fake     Fake
# Fake     Fake
# original original
# original Fake
# original original
# original original
# Fake     Fake
# original original
# original original
# Fake     Fake
# Fake     Fake
# original original
# original original
# original original
# Fake     original
# original original
# Fake     original
# Fake     original
# Fake     Fake
# original original
# Fake     Fake
# Fake     Fake
# original original
# original original
# original original
# Fake     Fake
# Fake     original
# original Fake
# original original
# Fake     Fake
# original original
# original original
# Fake     Fake
# original original
# Fake     Fake
# original original
# original original
# Fake     Fake
# original original
# Fake     Fake
# original original
# Fake     Fake
# Fake     Fake
# original Fake
# original original
# original original
# Fake     original
# original original
# Fake     Fake
# Fake     Fake
# original Fake
# Fake     Fake
# original original
# Fake     Fake
# original original
# original original
# Fake     Fake
# Fake     Fake
# original original
# original original
# original original
# original original
# original original
# original original
# Fake     Fake
# Fake     Fake
# original Fake
# Fake     Fake
# Fake     Fake
# Fake     Fake
# Fake     Fake
# original original
# original original
# original Fake
# original original
# original original
# original Fake
# original Fake
# Fake     Fake
# Fake     Fake
# original Fake
# Fake     Fake
# original original
# original original
# Fake     Fake
# original original
# original original
# Fake     Fake
# original Fake
# original original
# Fake     Fake
# original original
# original original
# Fake     original
# Fake     original
# Fake     Fake
# original Fake
# original original
# Fake     original
# Fake     original
# Fake     original
# Fake     Fake
# Fake     Fake
# Fake     Fake
# Fake     original
# original original
# Fake     original
# Fake     Fake
# Fake     Fake
# Fake     original
# Fake     Fake
# Fake     Fake
# original original
# original original
# original original
# Fake     Fake
# Fake     Fake
# Fake     Fake
# Fake     Fake
# original original
# original original
# original original
# Fake     Fake
# original Fake
# original original
# original original
# original original
# original original
# original Fake
# Fake     Fake
# original original
# Fake     Fake
# original Fake
# Fake     Fake
# Fake     original
# original original
# Fake     Fake
# Fake     Fake
# original Fake
# original original
# original Fake
# Fake     Fake
# original original
# Fake     Fake
# Fake     original
# Fake     Fake
# Fake     original
# Fake     original
# original original
# Fake     Fake
# original original
# Fake     Fake
# Fake     original
# original original
# Fake     Fake
# Fake     original
# Fake     Fake
# original Fake
# Fake     Fake
# original original
# Fake     Fake
# Fake     Fake
# Fake     Fake
# original original
# Fake     original
# Fake     Fake
# original original
# original Fake
# Fake     Fake
# Fake     Fake
# original original
# original original
# original original
# Fake     Fake
# Fake     original
# Fake     Fake
# Fake     Fake
# original original
# original original
# Fake     original
# original original
# original original
# Fake     Fake
# Fake     Fake
# Fake     Fake
# original original
# Fake     Fake
# original original
# Fake     Fake
# Fake     original
# original original
# original original
# original original
# original original
# original original
# Fake     Fake
# Fake     Fake
# Fake     Fake
# original original
# original original
# original original
# original Fake
# Fake     original
# Fake     Fake
# Fake     original
# Fake     Fake
# Fake     original
# original original
# Fake     Fake
# Fake     Fake
# original original
# original original
# original original
# original original
# original Fake
# Fake     Fake
# Fake     Fake
# original original
# original original
# Fake     Fake
# original original
# Fake     Fake
# Fake     Fake
# original original
# original original
# original Fake
# Fake     Fake
# original original
# original original
# Fake     Fake
# Fake     Fake
# Fake     Fake
# Fake     Fake
# original original
# original Fake
# original original
# Fake     Fake
# original original
# original original
# original original
# original Fake
# Fake     Fake
# original original
# Fake     Fake
# original original
# Fake     Fake
# original original
# original original
# Fake     Fake
# original original
# original original
# original original
# original original
# Fake     Fake
# original original
# original original
# original original
# original Fake
# original original
# original Fake
# original Fake
# original original
# Fake     Fake
# Fake     Fake
# original original
# original original
# Fake     Fake
# Fake     Fake
# original original
# Fake     Fake
# original original
# Fake     Fake
# original original
# Fake     Fake
# Fake     Fake
# Fake     Fake
# original Fake
# Fake     original
# original original
# Fake     Fake
# Fake     Fake
# Fake     Fake
# original original
# Fake     Fake
# Fake     Fake
# Fake     Fake
# Fake     Fake
# Fake     Fake
# original Fake
# original Fake
# Fake     Fake
# original original
# original Fake
# original original
# original original
# Fake     Fake
# original original
# original original
# Fake     original
# Fake     Fake
# Fake     original
# Fake     Fake
# original original
# original original
# Fake     Fake
# Fake     Fake
# Fake     Fake
# Fake     original
# original original
# original original
# original original
# Fake     Fake
# Fake     Fake
# original original
# original Fake
# original Fake
# Fake     Fake
# Fake     original
# original original
# Fake     Fake
# Fake     original
# Fake     Fake
# Fake     Fake
# original original
# original original
# original original
# original original
# original original
# Fake     Fake
# original original
# original original
# Fake     Fake
# original Fake
# original Fake
# Fake     Fake
# Fake     Fake
# Fake     Fake
# Fake     original
# Fake     Fake
# original original
# Fake     original
# original Fake
# Fake     Fake
# Fake     Fake
# original original
# Fake     Fake
# Fake     original
# original original
# Fake     Fake
# original original
# Fake     Fake
# original original
# original original
# original original
# Fake     Fake
# original original
# original original
# original original
# Fake     Fake
# original original
# Fake     Fake
# Fake     original
# original Fake
# Fake     original
# Fake     original
# original original
# original Fake
# Fake     original
# original original
# Fake     Fake
# original original
# Fake     original
# original original
# Fake     original
# Fake     Fake
# Fake     Fake
# original original
# Fake     Fake
# original original
# Fake     Fake
# original original
# Fake     Fake
# Fake     Fake
# original Fake
# original original
# original original
# Fake     Fake
# Fake     Fake
# original Fake
# original original
# Fake     Fake
# Fake     Fake
# Fake     Fake
# Fake     Fake
# original original
# Fake     original
# original original
# Fake     Fake
# Fake     Fake
# original Fake
# original original
# Fake     Fake
# Fake     Fake
# Fake     original
# original original
# original original
# Fake     Fake
# original original
# Fake     Fake
# Fake     original
# Fake     original
# Fake     Fake
# original original
# Fake     Fake
# Fake     Fake
# original Fake
# original original
# Fake     Fake
# Fake     Fake
# original original
# Fake     Fake
# Fake     Fake
# original original
# Fake     Fake
# original original
# Fake     Fake
# Fake     Fake
# Fake     Fake
# Fake     Fake
# original Fake
# Fake     Fake
# original original
# Fake     Fake
# original Fake
# Fake     Fake
# Fake     Fake
# Fake     original
# Fake     Fake
# Fake     original
# Fake     original
# original original
# original Fake
# original original
# Fake     Fake
# original original
# original original
# original original
# original original
# original original
# original original
# Fake     Fake
# original original
# original original
# original Fake
# Fake     Fake
# original original
# Fake     Fake
# original original
# original original
# Fake     Fake
# original original
# Fake     original
# original Fake
# Fake     Fake
# Fake     Fake
# original original
# original original
# original original
# original Fake
# original Fake
# Fake     Fake
# original original
# Fake     original
# original original
# Fake     original
# original original
# original original
# original original
# original original
# original Fake
# Fake     original
# original original
# original original
# original original
# original original
# original original
# Fake     original
# Fake     Fake
# original Fake
# original Fake
# Fake     original
# Fake     Fake
# original original
# original original
# original Fake
# Fake     Fake
# original original
# original original
# original original
# original original
# Fake     Fake
# Fake     Fake
# Fake     Fake
# original Fake
# Fake     Fake
# Fake     Fake
# original Fake
# original Fake
# original original
# original Fake
# Fake     Fake
# original Fake
# original original
# original Fake
# original Fake
# Fake     Fake
# Fake     Fake
# Fake     original
# Fake     original
# original original
# original original
# Fake     Fake
# original original
# Fake     Fake
# original original
# Fake     original
# original original
# original original
# original original
# Fake     original
# Fake     Fake
# original original
# original original
# original original
# original original
# original original
# original original
# original original
# Fake     Fake
# Fake     Fake
# Fake     Fake
# original original
# Fake     Fake
# Fake     Fake
# original original
# original Fake
# original original
# original original
# Fake     Fake
# Fake     original
# original original
# Fake     Fake
# original original
# Fake     Fake
# original original
# Fake     Fake
# Fake     Fake
# original original
# original original
# original Fake
# Fake     original
# original original
# Fake     Fake
# original Fake
# Fake     Fake
# Fake     Fake
# Fake     Fake
# Fake     Fake
# Fake     Fake
# original original
# Fake     Fake
# original original
# Fake     Fake
# Fake     original
# Fake     original
# Fake     Fake
# Fake     Fake
# original original
# Fake     original
# Fake     Fake
# original Fake
# original original
# Fake     Fake
# Fake     Fake
# original original
# Fake     original
# original original
# original original
# Fake     Fake
# Fake     original
# Fake     Fake
# Fake     Fake
# original original
# Fake     Fake
# original original
# original original
# original Fake
# original original
# Fake     Fake
# original original
# Fake     original
# Fake     original
# original Fake
# Fake     original
# original original
# Fake     Fake
# original original
# Fake     Fake
# Fake     Fake
# Fake     Fake
# Fake     Fake
# Fake     Fake
# original original
# Fake     Fake
# Fake     Fake
# original Fake
# Fake     Fake
# original original
# original original
# original original
# Fake     original
# original original
# original original
# original original
# original original
# Fake     Fake
# Fake     original
# original original

# %% [markdown]
# ### Inference

# %%
print("NB Accuracy: ",accuracy_nb)
print("SVM Accuracy: ",accuracy_svm)
print("RF Accuracy: ",accuracy_rf)
print("LR Accuracy: ",accuracy_lr)
# Out:
# NB Accuracy:  0.788957055215
# SVM Accuracy:  0.501840490798
# RF Accuracy:  0.755828220859
# LR Accuracy:  0.786503067485

# %% [markdown]
# ### Applying NB in test data which is without label.

# %%
test_without_label = pd.read_csv('Fake_test_without_labels.csv')

# %%
x = vectorizer.transform(test_without_label['text'])

# %%
predictions_without_label_nb = classifier_nb.predict(x)

# %%
results_without_label_nb = pd.DataFrame({
    'Text': test_without_label['text'],
    'Predicted': predictions_without_label_nb
})

# %%
results_without_label_nb
# Out:
#      Predicted                                               Text
# 0         Fake  5000 ഉള്ള പോൾ  ലോഗ്‌ഡ്‌വൻ ഇപ്പോള് 250000 എന്താ...
# 1     original  ഓഷോ രജനീഷ്  പറഞ്ഞപോലെ  എനിക്കപ്പോൾ തോന്നിയത് അ...
# 2         Fake  ചേട്ടാ  വാർത്ത  വയ്ക്കുന്നത്  കേരളത്തിലാണ്  സം...
# 3         Fake                         Shame for entire Woman&#39
# 4         Fake  135 code janaghal andhu wide business cheythal...
# 5         Fake  Why not all countries club together n block ch...
# 6     original  Ethil appuram നാണക്കേഡ് വന്നിട്ടില്ല cpmne🤣🤣🤣a...
# 7     original  കൊറോണ പോയി ഒന്ന് കൂടെ മെച്ചപ്പെട്ട് ഓമൈക്രോനായ...
# 8     original  മോളെ. ഇത് കോമഡി സ്റ്റാർസ് അല്ല. ചിരിച്ചും കളിച...
# 9     original                           Marunaadan kandupidutham
# 10    original         ഈ പാട്ടിനു ആടിയ ചേച്ചീസിന്റെ തൊലിക്കട്ടി..
# 11    original  നിയമം അവർത്തന്നെ കൊണ്ടുവരും... എന്നിട്ടു അത് അ...
# 12        Fake  Corona  virus is a programmed VIRUS  created b...
# 13    original                                    ലേശം ഉളുപ്പ്..😁
# 14    original  ഇന്നീ വൈറസ്‌ ലോകമെങ്ങും,  വ്യാപിച്ചീടും കാരണഭൂ...
# 15        Fake  പല വസ്തുതകൾ   പഠന വിധേയമാക്കിയിട്ടില്ല . ചൈന  ...
# 16        Fake  ഒരുത്തൻ കൊലക്കത്തിക്ക് ഇരയായിട്ടു ഒരു ദിവസം കഴ...
# 17    original  താത്വിക ആചാര്യന്മാർക്ക് ഒരു കയ്യബദ്ധം... നാറ്റ...
# 18        Fake  Finally  ,world will be named and count, based...
# 19    original  Bengalikal egane namude nattil ethii ennu mana...
# 20    original                                          പ്രവാസി 😔
# 21        Fake  ഇത് ഉത്പാധിപ്പിച്ചു കീശയിൽ തുട്ട് വീഴുന്നത് ഇവ...
# 22        Fake                                   Allahuuu akbarr😢
# 23    original                                   Palte.  Mahtunu.
# 24    original  ഉറപ്പാണ് കോവിഡ്, ഒമിക്രോൺ വരും എല്ലാം ശരിയാവും...
# 25    original               എല്ലാം  വരുടെയും  പ്രാത്ഥന മൂലം  ആണ്
# 26    original  ശജഹാൻ ചേട്ടൻ ഒരു ബിഗ് സല്യൂട്ട് 💪💪ഇങ്ങനെ വേണം ...
# 27    original  ഇതു ബ്ലാക്ക്മാൻ വന്ന പോലെ ആയി. അവിടെ കണ്ടു ഇവി...
# 28        Fake  മണ്ടന്മാരായ ഡോക്ടർമാർ പറയുന്നത് മാത്രം വിശ്വസി...
# 29        Fake  ഈ പാട്ടുകേട്ടിരിക്കാൻ അപാര തൊലിക്കട്ടിതന്നെ വേ...
# ...        ...                                                ...
# 989   original  5 പൈസക്ക് ഉള്ള വിവരം ഉണ്ടോ ഈ നാറികൾക്ക്‌.........
# 990       Fake                                  Such a nuisance!!
# 991   original                                  നല്ല വഴികാട്ടി👍👍👍
# 992       Fake               Thiruvathira kali alkuttam alla sir👍
# 993   original               Haha... aashanu aduppilum ..th..raam
# 994       Fake                                         Virus ella
# 995   original                                      വീണ 😜 മന്ത്രി
# 996   original  ആദ്യമായിട്ട് ചെയ്യേണ്ടത് വീണാ ജോർജിനെ ആരോഗ്യ വ...
# 997       Fake  Ithoru manushya nirmitha virasaanu..   krthyam...
# 998       Fake  We didn&#39;t had summer in kerala this time b...
# 999       Fake  മനുഷ്യ നിർമിതം തന്നെ. പടരാൻ കാരണം ലോകാരോഗ്യ സം...
# 1000  original                                    Kashttam thanne
# 1001  original  Arkkum thonnunnillee orumathiri pottanmaaraan ...
# 1002      Fake  അതേ  എന്ത്  മഹാമാരി  വന്നാലും  കുറെ  ആകുമ്പോൾ ...
# 1003      Fake  Ima ഈസ്‌ illuminaati. അതാണ് അമേരിക്കയിൽ  ചികിത...
# 1004  original  Ivark okey athra athyavishamengil onlineil mee...
# 1005  original                Ivan ithu nale thirichum parayum...
# 1006      Fake  Oro covide perum paranju janagale patikune Kur...
# 1007      Fake  ലോകം മുഴുവനും ശോഭിച് ഇല്ലെങ്കിലും ഇന്ത്യയിൽ ഒന...
# 1008  original                          അപ്പോ മെയ്ഡ് ഇൻ ചൈന &quot
# 1009      Fake  It is the world war 3.0 and by the time the co...
# 1010      Fake  Enthuparyan evarekodu ulla gunam kity... Eni e...
# 1011  original                     എന്തിനോ ഒരു ആരോഗ്യ മന്ത്രി ...
# 1012  original  2ദിവസം കൂടി കഴിഞ്ഞാൽ എല്ലാവർക്കും കൂടി വീട്ടിൽ...
# 1013      Fake  കൊറോണ  കമ്മികള്ളുടെ  സ്വഭാവം കണ്ട്  അവിടെനിന്ന...
# 1014      Fake  Correct ...China cheitha ...weapon spread ing ...
# 1015      Fake  ഈ WHO പറയുന്നതനുസരിച്ചു ചികിത്സയും ലോക്ക് ഡൌൺ ...
# 1016  original                                 Mask illa aarkum😏😏
# 1017      Fake   ഇയാളെ  കൊറോണ. രോഗി കൾ കിടയിൽ. ഇടാമായിരുന്നു---!!
# 1018  original  Kulathrikalkku badilayiAlavilathikal          ...
#
# [1019 rows x 2 columns]

# %%
results_without_label_nb.to_csv('output_file_task1.csv', index=False)

# %%
df=results_without_label_nb

# %%
actual_labels = pd.read_csv('Dataset/Fake_test_with_labels1.csv')

# %%
merged_df = pd.merge(df, actual_labels, left_on='Text', right_on='text')

# %%
correct_predictions = merged_df['Predicted'] == merged_df['label']
accuracy = correct_predictions.sum() / len(correct_predictions)

print(f'Accuracy: {accuracy * 100:.2f}%')
# Out:
# Accuracy: 78.50%
